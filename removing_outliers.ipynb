# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample()  # display randomly any number of records of data
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 11                     0.537   34        1

# %%
df.dtypes  # list the types of data
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info()   # finding out if the dataset contains any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#statistical summery
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (768, 9)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (768, 9)

# %%
# check the null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# check the number of zero values in dataset

# %%
print('no. of zero values in Pregnancies', df[df['Pregnancies']==0].shape[0])
# Out:
# no. of zero values in Pregnancies 111

# %%
print('no. of zero values in Glucose', df[df['Glucose']==0].shape[0])
# Out:
# no. of zero values in Glucose 5

# %%
print('no. of zero values in BloodPressure', df[df['BloodPressure']==0].shape[0])
# Out:
# no. of zero values in BloodPressure 35

# %%
print('no. of zero values in SkinThickness', df[df['SkinThickness']==0].shape[0])
# Out:
# no. of zero values in SkinThickness 227

# %%
print('no. of zero values in Insulin', df[df['Insulin']==0].shape[0])
# Out:
# no. of zero values in Insulin 374

# %%
print('no. of zero values in BMI', df[df['BMI']==0].shape[0])
# Out:
# no. of zero values in BMI 11

# %% [markdown]
#  Replace number of zero values with mean of the columns

# %%
df['Pregnancies'] = df['Pregnancies'].replace (0,df['Pregnancies'].mean())
df['Glucose'] = df['Glucose'].replace (0,df['Glucose'].mean())
df['BloodPressure'] = df['BloodPressure'].replace (0,df['BloodPressure'].mean())
df['SkinThickness'] = df['SkinThickness'].replace (0,df['SkinThickness'].mean())
df['Insulin'] = df['Insulin'].replace (0,df['Insulin'].mean())
df['BMI'] = df['BMI'].replace (0,df['BMI'].mean())

# %%
print("no. of zero values in Pregnancies", df[df['Pregnancies']==0].shape[0])
print("no. of zero values in Glucose", df[df['Glucose']==0].shape[0])
print("no. of zero values in BloodPressure", df[df['BloodPressure']==0].shape[0])
print("no. of zero values in SkinThickness", df[df['SkinThickness']==0].shape[0])
print("no. of zero values in Insulin", df[df['Insulin']==0].shape[0])
print("no. of zero values in BMI", df[df['BMI']==0].shape[0])
# Out:
# no. of zero values in Pregnancies 0
# no. of zero values in Glucose 0
# no. of zero values in BloodPressure 0
# no. of zero values in SkinThickness 0
# no. of zero values in Insulin 0
# no. of zero values in BMI 0

# %%
df.describe()  # min row of every coiumn is replaced by mean
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      4.400782  121.681605      72.254807      26.606479  118.660163
# std       2.984162   30.436016      12.115932       9.631241   93.080358
# min       1.000000   44.000000      24.000000       7.000000   14.000000
# 25%       2.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.845052  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1. Count Plot & Box Plot

# %%
# outcome count plot
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_all_columns(df):
    num_cols = df.shape[1]-1
    fig, axes = plt.subplots(num_cols, 2, figsize=(12, 5*num_cols))
    
    for i, col_name in enumerate(df.columns[:-1]):
        sns.histplot(data=df, x=col_name, ax=axes[i, 0])
        sns.boxplot(data=df, y=col_name, ax=axes[i, 1])
        axes[i, 0].set_title(f'{col_name} - Histogram')
        axes[i, 1].set_title(f'{col_name} - Boxplot')
        axes[i, 0].set_ylabel('')
        axes[i, 1].set_ylabel('')
    
    plt.tight_layout()

# Example usage
visualize_all_columns(df)
plt.show()

# %%
try:
    #for figure having columns
    fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20,10))

    # Flatten the axes array to easily iterate over it
    axes = axes.flatten()

    # Loop through each column and plot a boxplot on each subplot
    for i, column in enumerate(df.columns):
        df[column].plot(kind='box', ax=axes[i])
        axes[i].set_title(column)

    
    plt.tight_layout()

    
    plt.show()

except IndexError:
    print("Number of columns in the DataFrame doesn't match the number of subplots requested.")
# Out:
# Number of columns in the DataFrame doesn't match the number of subplots requested.

# %% [markdown]
# # IQR & Capping - to remove outliers

# %%
def visualize_with_capping(df):
    capped_df = df.copy()
    for col in capped_df.columns[:-1]:
        q1 = capped_df[col].quantile(0.25)
        q3 = capped_df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        capped_df[col] = capped_df[col].clip(lower=lower_bound, upper=upper_bound)
    

    num_cols = capped_df.shape[1] - 1  
    fig, axes = plt.subplots(num_cols, 2, figsize=(12, 5*num_cols))
    
    for i, col_name in enumerate(capped_df.columns[:-1]):  
        sns.histplot(data=capped_df, x=col_name, ax=axes[i, 0])
        sns.boxplot(data=capped_df, y=col_name, ax=axes[i, 1])
        axes[i, 0].set_title(f'{col_name} - Histogram')
        axes[i, 1].set_title(f'{col_name} - Boxplot')
        axes[i, 0].set_ylabel('')
        axes[i, 1].set_ylabel('')
    
    plt.tight_layout()

visualize_with_capping(df)
plt.show()

# %% [markdown]
# # Analyzing relationship between variables

# %% [markdown]
# Correlation Analysis

# %%
import seaborn as sns

cm = df.corr()
top_corr_features = cm.index

plt.figure(figsize=(10,10))
g =sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Split the data into X & Y

# %%
target = 'Outcome'

y = df[target]

x = df.drop(target , axis=1)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # Apply Feature Scaling

# %%
# Apply standar scaler
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
scaler.fit(x)
ssx = scaler.transform(x)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(ssx, y, test_size=0.2, random_state=7)

# %%
x_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
x_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# # Build the Classification Algorithm

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver = 'liblinear',multi_class= 'ovr')
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
# K-Nearest neighbors classifier KNN

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Naive-Bayes Classifier

from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
# Support Vector Machine SVM

from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
# Decission Tress Classifier

from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Random Forest 

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(criterion = 'entropy')
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %% [markdown]
# # Making Predictions

# %%
# making prediction on test data using logistic regression
lr_pred = lr.predict(x_test)

# making prediction on test data using KNN
knn_pred = knn.predict(x_test)

# making prediction on test data using Naive Bayes
nb_pred = nb.predict(x_test)

# making prediction on test data using SVM
sv_pred =sv.predict(x_test)

# making prediction on test data using Decision Tree
dt_pred = dt.predict(x_test)

# making prediction on test data using Random forest
rf_pred = rf.predict(x_test)

# %% [markdown]
# # Model Evalution

# %% [markdown]
# Train Score & Test Score

# %%
from sklearn.metrics import accuracy_score

# %%
#Train and Test Score of logistic regression

print("Train Accuracy of logistic regression :",lr.score(x_train,y_train)*100)
print("Test Accuracy of logistic regression :",lr.score(x_test,y_test)*100)
print("Accuracy Score of logistic regression :",accuracy_score(y_test,lr_pred)*100)
# Out:
# Train Accuracy of logistic regression : 78.50162866449512
# Test Accuracy of logistic regression : 77.27272727272727
# Accuracy Score of logistic regression : 77.27272727272727

# %%
#Train and Test Score of KNN

print("Train Accuracy of KNN :",knn.score(x_train,y_train)*100)
print("Test Accuracy of KNN :",knn.score(x_test,y_test)*100)
print("Accuracy Score of KNN :",accuracy_score(y_test,knn_pred)*100)
# Out:
# Train Accuracy of KNN : 79.80456026058633
# Test Accuracy of KNN : 75.97402597402598
# Accuracy Score of KNN : 75.97402597402598

# %%
#Train and Test Score of Naive Bayes

print("Train Accuracy of Naive Bayes :",nb.score(x_train,y_train)*100)
print("Test Accuracy of Naive Bayes :",nb.score(x_test,y_test)*100)
print("Accuracy Score of Naive Bayes :",accuracy_score(y_test,nb_pred)*100)
# Out:
# Train Accuracy of Naive Bayes : 74.1042345276873
# Test Accuracy of Naive Bayes : 75.32467532467533
# Accuracy Score of Naive Bayes : 75.32467532467533

# %%
#Train and Test Score of SVM

print("Train Accuracy of SVM :",sv.score(x_train,y_train)*100)
print("Test Accuracy of SVM :",sv.score(x_test,y_test)*100)
print("Accuracy Score of SVM :",accuracy_score(y_test,sv_pred)*100)
# Out:
# Train Accuracy of SVM : 81.59609120521174
# Test Accuracy of SVM : 81.81818181818183
# Accuracy Score of SVM : 81.81818181818183

# %%
#Train and Test Score of Decision Tree

print("Train Accuracy of Decision Tree :",dt.score(x_train,y_train)*100)
print("Test Accuracy of Decision Tree :",dt.score(x_test,y_test)*100)
print("Accuracy Score of Decision Tree :",accuracy_score(y_test,dt_pred)*100)
# Out:
# Train Accuracy of Decision Tree : 100.0
# Test Accuracy of Decision Tree : 79.87012987012987
# Accuracy Score of Decision Tree : 79.87012987012987

# %%
#Train and Test Score of Random forest

print("Train Accuracy of Random forest :",rf.score(x_train,y_train)*100)
print("Test Accuracy of Random forest :",rf.score(x_test,y_test)*100)
print("Accuracy Score of Random forest :",accuracy_score(y_test,rf_pred)*100)
# Out:
# Train Accuracy of Random forest : 100.0
# Test Accuracy of Random forest : 81.81818181818183
# Accuracy Score of Random forest : 81.81818181818183

# %% [markdown]
# # Confusion Matrix
#
# Confusion matrix is a table which is used to describe the performance of a classification problem.
#
# It visualize the accuracy of a classifier by comparing predicted values with actual values.
#
# the terms in cm:
#
# __True Postive__: The predicted result is +ve, while it is labelled as +ve
#
# __False Positive__:The predicted result is +ve, while it is labelled as -ve
#
# __False Negative__:The predicted result is -ve, while it is labelled as +ve
#
# __True Negative__:The predicted result is -ve, while it is labelled as -ve

# %%
from sklearn.metrics import classification_report , confusion_matrix
cm = confusion_matrix(y_test,lr_pred)
cm
# Out:
# array([[86, 11],
#        [24, 33]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,lr_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of Logistic Regression :\n",classification_report(y_test,lr_pred))
# Out:
# Classification Report of Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83        97
#            1       0.75      0.58      0.65        57
#
#     accuracy                           0.77       154
#    macro avg       0.77      0.73      0.74       154
# weighted avg       0.77      0.77      0.77       154

# %%
#confusion matrix and classification report of KNN

cm = confusion_matrix(y_test,knn_pred)
cm
# Out:
# array([[81, 16],
#        [21, 36]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,knn_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of KNN :\n",classification_report(y_test,knn_pred))
# Out:
# Classification Report of KNN :
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81        97
#            1       0.69      0.63      0.66        57
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.73      0.74       154
# weighted avg       0.76      0.76      0.76       154

# %%
#confusion matrix and classification report of Naive Bayes
cm = confusion_matrix(y_test,nb_pred)
cm
# Out:
# array([[79, 18],
#        [20, 37]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,nb_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of Logistic Regression :\n",classification_report(y_test,nb_pred))
# Out:
# Classification Report of Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81        97
#            1       0.67      0.65      0.66        57
#
#     accuracy                           0.75       154
#    macro avg       0.74      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154

# %%
#confusion matrix and classification report of SVM 
cm = confusion_matrix(y_test,sv_pred)
cm
# Out:
# array([[91,  6],
#        [22, 35]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,sv_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of SVM :\n",classification_report(y_test,sv_pred))
# Out:
# Classification Report of SVM :
#                precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        97
#            1       0.85      0.61      0.71        57
#
#     accuracy                           0.82       154
#    macro avg       0.83      0.78      0.79       154
# weighted avg       0.82      0.82      0.81       154

# %%
#confusion matrix and classification report of Decision Tree
cm = confusion_matrix(y_test,dt_pred)
cm
# Out:
# array([[80, 17],
#        [14, 43]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,dt_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of Decision Tree :\n",classification_report(y_test,dt_pred))
# Out:
# Classification Report of Decision Tree :
#                precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84        97
#            1       0.72      0.75      0.74        57
#
#     accuracy                           0.80       154
#    macro avg       0.78      0.79      0.79       154
# weighted avg       0.80      0.80      0.80       154

# %%
#confusion matrix and classification report of Random forest
cm = confusion_matrix(y_test,rf_pred)
cm
# Out:
# array([[86, 11],
#        [17, 40]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,rf_pred),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print("Classification Report of Random forest :\n",classification_report(y_test,rf_pred))
# Out:
# Classification Report of Random forest :
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        97
#            1       0.78      0.70      0.74        57
#
#     accuracy                           0.82       154
#    macro avg       0.81      0.79      0.80       154
# weighted avg       0.82      0.82      0.82       154
